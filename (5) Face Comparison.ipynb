# %%
pip install deepface

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("defne_foto11.jpg")
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
img2=cv2.imread("defne_foto22.jpg")
plt.imshow(img2[:,:,::-1])
plt.show()

# %%
result=DeepFace.verify(img1,img2)

# %%
result["verified"]
# Out:
# True

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.27375878153166067,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}

# %%
img3=cv2.imread("sefa.jpg")
plt.imshow(img3[:,:,::-1])
plt.show()

# %%
result=DeepFace.verify(img1,img3)

# %%
result
# Out:
# {'verified': False,
#  'distance': 0.6528210609940537,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}
